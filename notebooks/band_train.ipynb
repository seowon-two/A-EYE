# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 62.3 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive/26-1 오소프 /label"
# Out:
# band.yolov8.zip		       festal.yolov8.zip       panpirin.yolov8.zip
# bearse.yolov8.zip	       fusidin.yolov8.zip      patch.yolov8.zip
# eyedrop_multi.yolov8.zip       geborin.v3i.yolov8.zip  tylenol.yolov8.zip
# eyedrop_single.v1i.yolov8.zip  madecassol.yolov8.zip
# ezen6.v1i.yolov8.zip	       pancol.v1i.yolov8.zip

# %%
# !unzip -o "/content/drive/MyDrive/26-1 오소프 /label/band.yolov8.zip" -d /content/band
# Out:
# Archive:  /content/drive/MyDrive/26-1 오소프 /label/band.yolov8.zip
#  extracting: /content/band/test/images/band_32_jpg.rf.7082b7dc175c995c260660d10d449391.jpg
#  extracting: /content/band/test/images/band_31_jpg.rf.66fe16ceb9a733d5d9c3aed1f7df2be0.jpg
#  extracting: /content/band/test/images/band_35_jpg.rf.77fbf344e8e4748521e85f6d46d4d064.jpg
#  extracting: /content/band/test/images/band_28_jpg.rf.7352a59e855c2584c445b285e6daf66c.jpg
#  extracting: /content/band/test/images/band_20_jpg.rf.9cf0ddf9e1ac7b718ae3832b091b049b.jpg
#  extracting: /content/band/test/images/band_38_jpg.rf.114ff44028023682bef7d8b28c33c7ab.jpg
#  extracting: /content/band/train/images/band_27_jpg.rf.b493de051332c32cd0842b7d017cc03f.jpg
#  extracting: /content/band/train/images/band_57_jpg.rf.be4879ff6127850e49338d6310248125.jpg
#  extracting: /content/band/train/images/band_48_jpg.rf.c2b33f65fa208e466736b401932e62cb.jpg
# ...

# %%
# !ls /content/band
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/band/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    name="band_train"
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.54 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !ls runs/detect/band_train/weights
# Out:
# best.pt  last.pt

# %%
from google.colab import files
files.download("runs/detect/band_train/weights/best.pt")
