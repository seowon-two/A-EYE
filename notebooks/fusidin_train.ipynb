# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 49.0 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive/26-1 오소프 /label"
# Out:
# band.yolov8.zip		       festal.yolov8.zip       panpirin.yolov8.zip
# bearse.yolov8.zip	       fusidin.yolov8.zip      patch.yolov8.zip
# eyedrop_multi.yolov8.zip       geborin.v3i.yolov8.zip  tylenol.yolov8.zip
# eyedrop_single.v1i.yolov8.zip  madecassol.yolov8.zip
# ezen6.v1i.yolov8.zip	       pancol.v1i.yolov8.zip

# %%
# !unzip -o "/content/drive/MyDrive/26-1 오소프 /label/fusidin.yolov8.zip" -d /content/fusidin
# Out:
# Archive:  /content/drive/MyDrive/26-1 오소프 /label/fusidin.yolov8.zip
#  extracting: /content/fusidin/test/images/fusidin_27_jpg.rf.c83772b689e8c0acb25a3a324b149b06.jpg
#  extracting: /content/fusidin/test/images/fusidin_35_jpg.rf.ef36d7d58ff878e16062efc7cfda247e.jpg
#  extracting: /content/fusidin/test/images/fusidin_36_jpg.rf.02e840397f3b3ebdbe49bffa45d72661.jpg
#  extracting: /content/fusidin/test/images/fusidin_04_jpg.rf.35196f47ed93207e58dc8c81eb0d75ff.jpg
#  extracting: /content/fusidin/test/images/fusidin_01_jpg.rf.44bb598a0142a87e2b375e3d26b23913.jpg
#  extracting: /content/fusidin/train/images/fusidin_45_jpg.rf.7033747a1e07150d62667443237c3597.jpg
#  extracting: /content/fusidin/train/images/fusidin_07_jpg.rf.1a4183648454a0f6d3267f2d5b1f2824.jpg
#  extracting: /content/fusidin/train/images/fusidin_28_jpg.rf.d9075e36bdf06e449a46941566f63d7e.jpg
#  extracting: /content/fusidin/train/images/fusidin_50_jpg.rf.3ce398bf4e9205ca60024b7ecb958c9e.jpg
# ...

# %%
# !ls /content/fusidin
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/fusidin/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    name="fusidin_train"
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.54 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !ls runs/detect/fusidin_train/weights
# Out:
# best.pt  last.pt

# %%
from google.colab import files
files.download("runs/detect/fusidin_train/weights/best.pt")
