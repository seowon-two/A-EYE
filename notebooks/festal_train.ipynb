# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 64.6 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive/26-1 오소프 /label"
# Out:
# band.yolov8.zip		       festal.yolov8.zip       panpirin.yolov8.zip
# bearse.yolov8.zip	       fusidin.yolov8.zip      patch.yolov8.zip
# eyedrop_multi.yolov8.zip       geborin.v3i.yolov8.zip  tylenol.yolov8.zip
# eyedrop_single.v1i.yolov8.zip  madecassol.yolov8.zip
# ezen6.v1i.yolov8.zip	       pancol.v1i.yolov8.zip

# %%
# !unzip -o "/content/drive/MyDrive/26-1 오소프 /label/festal.yolov8.zip" -d /content/festal
# Out:
# Archive:  /content/drive/MyDrive/26-1 오소프 /label/festal.yolov8.zip
#  extracting: /content/festal/test/images/festal_44_jpg.rf.1b6330badc44146d172a1c34025d51ec.jpg
#  extracting: /content/festal/test/images/festal_46_jpg.rf.b43ea88d37106155d682f1c3dfd864f2.jpg
#  extracting: /content/festal/test/images/festal_25_jpg.rf.a35b642479c4f514c35c47a7ef6ad0c4.jpg
#  extracting: /content/festal/test/images/festal_10_jpg.rf.10e0631f8949072ba83db6aa478e7e4e.jpg
#  extracting: /content/festal/test/images/festal_04_jpg.rf.55fee2c6280784f90d1a35bcce095cdc.jpg
#  extracting: /content/festal/train/images/festal_45_jpg.rf.6e42c9374be87caa62786599f6a3324e.jpg
#  extracting: /content/festal/test/images/festal_71_jpg.rf.3cb947ea8172dc9c6871251588be2ad1.jpg
#  extracting: /content/festal/train/images/festal_21_jpg.rf.4b8a73b92d4f3ccee110a321a791e01b.jpg
#  extracting: /content/festal/train/images/festal_17_jpg.rf.9f632c68513ce248a3b513b2a8d99e45.jpg
# ...

# %%
# !ls /content/festal
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/festal/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    name="festal_train"
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.54 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !ls runs/detect/festal_train/weights
# Out:
# best.pt  last.pt

# %%
from google.colab import files
files.download("runs/detect/festal_train/weights/best.pt")
